# %% [markdown]
# <a href="https://colab.research.google.com/github/DataAnalytics808/DASC-522-demo-repository/blob/main/demos/Week_06_2_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##6B Optimization

# %%
# demo extensively modified from https://machinelearningmastery.com/how-to-accelerate-learning-of-deep-neural-networks-with-batch-normalization/

# mlp overfit on the moons dataset with simple early stopping
from sklearn.datasets import make_circles
from sklearn.datasets import make_moons

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
# from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization # <---- new

# from keras.optimizers import SGD #
from tensorflow.keras.optimizers import SGD # <---- new

from matplotlib import pyplot


from matplotlib import pyplot
import numpy as np
import pandas as pd
import keras

# generate 2d classification dataset
X, y = make_circles(n_samples=1000, noise=0.1, random_state=1)
# X, y = make_moons(n_samples=1000, noise=0.2, random_state=1)

# scatter plot, dots colored by class value
df = pd.DataFrame(dict(x=X[:,0], y=X[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots(figsize=(10,10))
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

# plt.figure(figsize=(20,10))

# split into train and test
n_train = 500
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]

# %% [markdown]
# Plot training / test sets

# %%
# plot training
print('----------training plot---------')
df2 = pd.DataFrame(dict(x=trainX[:,0], y=trainX[:,1], label=trainy))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots(figsize=(10,10))
grouped = df2.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()


# plot test
print('----------test plot---------')
df2 = pd.DataFrame(dict(x=testX[:,0], y=testX[:,1], label=testy))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots(figsize=(10,10))
grouped = df2.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()
# Out:
# ----------training plot---------
# ----------test plot---------

# %% [markdown]
# Model without batch normalization

# %%
# define model (2 moons, no early stopping)
# model = Sequential()
# model.add(Dense(500, input_dim=2, activation='relu'))
# model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# define model without BatchNormalization and weight initialization
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# simple early stopping
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=1)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# plot training history
pyplot.figure(figsize=(10,10))
pyplot.plot(history.history['accuracy'], label='train', )
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.4620 - loss: 0.7624 - val_accuracy: 0.5060 - val_loss: 0.6852
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5400 - loss: 0.6842 - val_accuracy: 0.4920 - val_loss: 0.6949
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5420 - loss: 0.6791 - val_accuracy: 0.5200 - val_loss: 0.6849
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5260 - loss: 0.6721 - val_accuracy: 0.5040 - val_loss: 0.6731
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5420 - loss: 0.6652 - val_accuracy: 0.5240 - val_loss: 0.6723
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5900 - loss: 0.6609 - val_accuracy: 0.5760 - val_loss: 0.6692
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6260 - loss: 0.6570 - val_accuracy: 0.5520 - val_loss: 0.6605
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5580 - loss: 0.6541 - val_accuracy: 0.5860 - val_loss: 0.6579
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7040 - loss: 0.6472 - val_accuracy: 0.6240 - val_loss: 0.6519
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5840 - loss: 0.6449 - val_accuracy: 0.6400 - val_loss: 0.6469
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6800 - loss: 0.6410 - val_accuracy: 0.6200 - val_loss: 0.6455
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6760 - loss: 0.6351 - val_accuracy: 0.6560 - val_loss: 0.6376
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6440 - loss: 0.6342 - val_accuracy: 0.6420 - val_loss: 0.6385
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7320 - loss: 0.6253 - val_accuracy: 0.7480 - val_loss: 0.6279
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7060 - loss: 0.6200 - val_accuracy: 0.6500 - val_loss: 0.6252
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7060 - loss: 0.6150 - val_accuracy: 0.7460 - val_loss: 0.6225
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7460 - loss: 0.6139 - val_accuracy: 0.7200 - val_loss: 0.6192
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7580 - loss: 0.6069 - val_accuracy: 0.7340 - val_loss: 0.6115
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7120 - loss: 0.6062 - val_accuracy: 0.7460 - val_loss: 0.6087
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7680 - loss: 0.5995 - val_accuracy: 0.7560 - val_loss: 0.6043
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7460 - loss: 0.5969 - val_accuracy: 0.7780 - val_loss: 0.6010
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7620 - loss: 0.5921 - val_accuracy: 0.7500 - val_loss: 0.5947
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7680 - loss: 0.5873 - val_accuracy: 0.7780 - val_loss: 0.5917
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7720 - loss: 0.5835 - val_accuracy: 0.7980 - val_loss: 0.5866
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7960 - loss: 0.5812 - val_accuracy: 0.7840 - val_loss: 0.5838
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7800 - loss: 0.5748 - val_accuracy: 0.7840 - val_loss: 0.5802
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7700 - loss: 0.5719 - val_accuracy: 0.7800 - val_loss: 0.5767
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7860 - loss: 0.5674 - val_accuracy: 0.8100 - val_loss: 0.5702
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.5648 - val_accuracy: 0.8040 - val_loss: 0.5679
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7900 - loss: 0.5625 - val_accuracy: 0.7920 - val_loss: 0.5649
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7800 - loss: 0.5583 - val_accuracy: 0.8200 - val_loss: 0.5577
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7820 - loss: 0.5540 - val_accuracy: 0.8080 - val_loss: 0.5549
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.5510 - val_accuracy: 0.8340 - val_loss: 0.5525
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7780 - loss: 0.5478 - val_accuracy: 0.8100 - val_loss: 0.5482
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.5421 - val_accuracy: 0.8320 - val_loss: 0.5446
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.5398 - val_accuracy: 0.8200 - val_loss: 0.5407
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7960 - loss: 0.5371 - val_accuracy: 0.8160 - val_loss: 0.5370
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.5334 - val_accuracy: 0.8260 - val_loss: 0.5361
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8080 - loss: 0.5287 - val_accuracy: 0.8100 - val_loss: 0.5304
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.5267 - val_accuracy: 0.8420 - val_loss: 0.5261
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.5226 - val_accuracy: 0.8440 - val_loss: 0.5211
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8220 - loss: 0.5198 - val_accuracy: 0.8240 - val_loss: 0.5205
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.5209 - val_accuracy: 0.8420 - val_loss: 0.5140
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7940 - loss: 0.5179 - val_accuracy: 0.8340 - val_loss: 0.5124
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8080 - loss: 0.5094 - val_accuracy: 0.8460 - val_loss: 0.5066
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8260 - loss: 0.5071 - val_accuracy: 0.8420 - val_loss: 0.5084
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8260 - loss: 0.5038 - val_accuracy: 0.8480 - val_loss: 0.5016
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8160 - loss: 0.4997 - val_accuracy: 0.8320 - val_loss: 0.4980
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8240 - loss: 0.4999 - val_accuracy: 0.8360 - val_loss: 0.4957
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8120 - loss: 0.4959 - val_accuracy: 0.8320 - val_loss: 0.4912
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8080 - loss: 0.4978 - val_accuracy: 0.8380 - val_loss: 0.4927
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8140 - loss: 0.4916 - val_accuracy: 0.8320 - val_loss: 0.4849
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8180 - loss: 0.4879 - val_accuracy: 0.8580 - val_loss: 0.4856
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8260 - loss: 0.4829 - val_accuracy: 0.8300 - val_loss: 0.4805
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8140 - loss: 0.4815 - val_accuracy: 0.8420 - val_loss: 0.4769
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8300 - loss: 0.4791 - val_accuracy: 0.8580 - val_loss: 0.4737
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8160 - loss: 0.4780 - val_accuracy: 0.8500 - val_loss: 0.4694
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4739 - val_accuracy: 0.8440 - val_loss: 0.4693
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4714 - val_accuracy: 0.8360 - val_loss: 0.4660
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8220 - loss: 0.4680 - val_accuracy: 0.8460 - val_loss: 0.4612
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8160 - loss: 0.4668 - val_accuracy: 0.8560 - val_loss: 0.4579
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4648 - val_accuracy: 0.8440 - val_loss: 0.4582
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4671 - val_accuracy: 0.8420 - val_loss: 0.4550
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.4618 - val_accuracy: 0.8480 - val_loss: 0.4552
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4584 - val_accuracy: 0.8560 - val_loss: 0.4491
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4546 - val_accuracy: 0.8400 - val_loss: 0.4462
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4535 - val_accuracy: 0.8620 - val_loss: 0.4448
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8220 - loss: 0.4502 - val_accuracy: 0.8360 - val_loss: 0.4432
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4472 - val_accuracy: 0.8420 - val_loss: 0.4381
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.4469 - val_accuracy: 0.8460 - val_loss: 0.4349
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4452 - val_accuracy: 0.8460 - val_loss: 0.4356
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4432 - val_accuracy: 0.8400 - val_loss: 0.4317
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4409 - val_accuracy: 0.8360 - val_loss: 0.4322
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4402 - val_accuracy: 0.8500 - val_loss: 0.4274
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8300 - loss: 0.4364 - val_accuracy: 0.8540 - val_loss: 0.4283
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4338 - val_accuracy: 0.8500 - val_loss: 0.4220
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.4323 - val_accuracy: 0.8480 - val_loss: 0.4222
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4339 - val_accuracy: 0.8420 - val_loss: 0.4212
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4296 - val_accuracy: 0.8420 - val_loss: 0.4195
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8220 - loss: 0.4290 - val_accuracy: 0.8480 - val_loss: 0.4157
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8300 - loss: 0.4272 - val_accuracy: 0.8560 - val_loss: 0.4184
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8260 - loss: 0.4250 - val_accuracy: 0.8500 - val_loss: 0.4138
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.4246 - val_accuracy: 0.8460 - val_loss: 0.4148
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4219 - val_accuracy: 0.8520 - val_loss: 0.4097
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4209 - val_accuracy: 0.8560 - val_loss: 0.4093
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8340 - loss: 0.4201 - val_accuracy: 0.8520 - val_loss: 0.4074
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4200 - val_accuracy: 0.8480 - val_loss: 0.4098
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8380 - loss: 0.4180 - val_accuracy: 0.8500 - val_loss: 0.4070
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8180 - loss: 0.4191 - val_accuracy: 0.8380 - val_loss: 0.4036
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8360 - loss: 0.4143 - val_accuracy: 0.8540 - val_loss: 0.4059
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.4168 - val_accuracy: 0.8500 - val_loss: 0.4035
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4136 - val_accuracy: 0.8420 - val_loss: 0.4015
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.4131 - val_accuracy: 0.8420 - val_loss: 0.4010
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4121 - val_accuracy: 0.8580 - val_loss: 0.3989
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4108 - val_accuracy: 0.8500 - val_loss: 0.3974
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8260 - loss: 0.4101 - val_accuracy: 0.8520 - val_loss: 0.3975
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8220 - loss: 0.4106 - val_accuracy: 0.8460 - val_loss: 0.3965
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4090 - val_accuracy: 0.8520 - val_loss: 0.3970
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8340 - loss: 0.4077 - val_accuracy: 0.8520 - val_loss: 0.3941
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8260 - loss: 0.4055 - val_accuracy: 0.8480 - val_loss: 0.3912
# Train: 0.830, Test: 0.848

# %% [markdown]
# Visualize output

# %%
# code from https://rohitmidha23.github.io/Neural-Network-Decision-Boundary/

import matplotlib.pyplot as plt
# %matplotlib inline

def plot_decision_boundary(X, y, model, steps=400, cmap='Paired'):
    cmap = plt.get_cmap(cmap)

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min() - 1, X[:,0].max() + 1
    ymin, ymax = X[:,1].min() - 1, X[:,1].max() + 1
    # steps = 400
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])

    # Plot decision boundary in region of interest
    z = labels.reshape(xx.shape)

    fig, ax = plt.subplots(figsize=(10,10))

    ax.contourf(xx, yy, z, cmap=cmap, alpha=0.5)

    # Get predicted labels on training data and plot
    train_labels = model.predict(X)
    ax.scatter(X[:,0], X[:,1], c=y, cmap=cmap, lw=0)

    return fig, ax

plot_decision_boundary(X, y, model, cmap='RdBu')
# Out:
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# (<Figure size 1000x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# Model with batch normalization

# %%
# define model
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization()) # <------ added
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])


# fit model
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=1)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# plot history
pyplot.figure(figsize=(10,10))
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.5980 - loss: 0.7455 - val_accuracy: 0.4960 - val_loss: 0.9711
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7180 - loss: 0.5704 - val_accuracy: 0.4960 - val_loss: 1.0218
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7740 - loss: 0.5066 - val_accuracy: 0.4960 - val_loss: 1.0390
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.4738 - val_accuracy: 0.4960 - val_loss: 0.9919
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7860 - loss: 0.4673 - val_accuracy: 0.5040 - val_loss: 0.9422
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7920 - loss: 0.4596 - val_accuracy: 0.5080 - val_loss: 0.8900
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4573 - val_accuracy: 0.5420 - val_loss: 0.7897
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.4311 - val_accuracy: 0.5920 - val_loss: 0.7227
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7940 - loss: 0.4461 - val_accuracy: 0.6180 - val_loss: 0.6830
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8220 - loss: 0.4298 - val_accuracy: 0.6840 - val_loss: 0.5953
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4409 - val_accuracy: 0.6880 - val_loss: 0.5853
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4363 - val_accuracy: 0.7100 - val_loss: 0.5368
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4122 - val_accuracy: 0.7460 - val_loss: 0.4877
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7960 - loss: 0.4404 - val_accuracy: 0.7720 - val_loss: 0.4603
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.4217 - val_accuracy: 0.7680 - val_loss: 0.4574
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7680 - loss: 0.4847 - val_accuracy: 0.7980 - val_loss: 0.4300
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7980 - loss: 0.4419 - val_accuracy: 0.7900 - val_loss: 0.4325
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4259 - val_accuracy: 0.8060 - val_loss: 0.4132
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4402 - val_accuracy: 0.8060 - val_loss: 0.4065
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8080 - loss: 0.4425 - val_accuracy: 0.8240 - val_loss: 0.3940
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8000 - loss: 0.4459 - val_accuracy: 0.8200 - val_loss: 0.3933
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8020 - loss: 0.4222 - val_accuracy: 0.8300 - val_loss: 0.3928
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8060 - loss: 0.4493 - val_accuracy: 0.8300 - val_loss: 0.3878
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8200 - loss: 0.4244 - val_accuracy: 0.8320 - val_loss: 0.3816
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7900 - loss: 0.4392 - val_accuracy: 0.8420 - val_loss: 0.3776
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.4062 - val_accuracy: 0.8360 - val_loss: 0.3773
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4273 - val_accuracy: 0.8320 - val_loss: 0.3763
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.4167 - val_accuracy: 0.8360 - val_loss: 0.3738
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7840 - loss: 0.4327 - val_accuracy: 0.8360 - val_loss: 0.3737
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7800 - loss: 0.4537 - val_accuracy: 0.8300 - val_loss: 0.3698
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7980 - loss: 0.4261 - val_accuracy: 0.8360 - val_loss: 0.3694
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4443 - val_accuracy: 0.8380 - val_loss: 0.3702
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7900 - loss: 0.4413 - val_accuracy: 0.8400 - val_loss: 0.3817
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8220 - loss: 0.4140 - val_accuracy: 0.8440 - val_loss: 0.3678
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7600 - loss: 0.4787 - val_accuracy: 0.8380 - val_loss: 0.3938
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7940 - loss: 0.4267 - val_accuracy: 0.8480 - val_loss: 0.3665
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7740 - loss: 0.4481 - val_accuracy: 0.8460 - val_loss: 0.3709
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7800 - loss: 0.4567 - val_accuracy: 0.8240 - val_loss: 0.3745
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7740 - loss: 0.4606 - val_accuracy: 0.8500 - val_loss: 0.3678
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8180 - loss: 0.4172 - val_accuracy: 0.8280 - val_loss: 0.3761
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7820 - loss: 0.4565 - val_accuracy: 0.8280 - val_loss: 0.3795
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8100 - loss: 0.4138 - val_accuracy: 0.8300 - val_loss: 0.3718
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8140 - loss: 0.4166 - val_accuracy: 0.8500 - val_loss: 0.3678
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8020 - loss: 0.4341 - val_accuracy: 0.8480 - val_loss: 0.3645
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8240 - loss: 0.4062 - val_accuracy: 0.8500 - val_loss: 0.3673
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8000 - loss: 0.4383 - val_accuracy: 0.8460 - val_loss: 0.3679
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7980 - loss: 0.4651 - val_accuracy: 0.8560 - val_loss: 0.3638
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8020 - loss: 0.4519 - val_accuracy: 0.8520 - val_loss: 0.3639
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7980 - loss: 0.4465 - val_accuracy: 0.8520 - val_loss: 0.3656
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4092 - val_accuracy: 0.8400 - val_loss: 0.3702
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.4191 - val_accuracy: 0.8380 - val_loss: 0.3776
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7840 - loss: 0.4465 - val_accuracy: 0.8420 - val_loss: 0.3628
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4227 - val_accuracy: 0.8420 - val_loss: 0.3792
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7620 - loss: 0.4712 - val_accuracy: 0.8500 - val_loss: 0.3697
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8140 - loss: 0.4209 - val_accuracy: 0.8280 - val_loss: 0.3694
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8160 - loss: 0.4112 - val_accuracy: 0.8420 - val_loss: 0.3713
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4276 - val_accuracy: 0.8360 - val_loss: 0.3699
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8240 - loss: 0.4273 - val_accuracy: 0.8420 - val_loss: 0.3782
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4218 - val_accuracy: 0.8420 - val_loss: 0.3691
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8300 - loss: 0.4119 - val_accuracy: 0.8380 - val_loss: 0.3647
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8160 - loss: 0.4378 - val_accuracy: 0.8500 - val_loss: 0.3653
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8220 - loss: 0.4042 - val_accuracy: 0.8280 - val_loss: 0.3664
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4246 - val_accuracy: 0.8520 - val_loss: 0.3604
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7940 - loss: 0.4305 - val_accuracy: 0.8540 - val_loss: 0.3634
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.4302 - val_accuracy: 0.8340 - val_loss: 0.3720
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8060 - loss: 0.4096 - val_accuracy: 0.8360 - val_loss: 0.3680
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4271 - val_accuracy: 0.8460 - val_loss: 0.3666
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4028 - val_accuracy: 0.8420 - val_loss: 0.3682
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8000 - loss: 0.4379 - val_accuracy: 0.8520 - val_loss: 0.3671
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8080 - loss: 0.4373 - val_accuracy: 0.8440 - val_loss: 0.3622
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4201 - val_accuracy: 0.8380 - val_loss: 0.3752
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8200 - loss: 0.4182 - val_accuracy: 0.8480 - val_loss: 0.3638
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8280 - loss: 0.4089 - val_accuracy: 0.8460 - val_loss: 0.3649
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4286 - val_accuracy: 0.8440 - val_loss: 0.3632
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.4356 - val_accuracy: 0.8400 - val_loss: 0.3631
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8200 - loss: 0.4189 - val_accuracy: 0.8420 - val_loss: 0.3828
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7720 - loss: 0.4507 - val_accuracy: 0.8460 - val_loss: 0.3685
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8080 - loss: 0.4274 - val_accuracy: 0.8480 - val_loss: 0.3714
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4376 - val_accuracy: 0.8500 - val_loss: 0.3721
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4405 - val_accuracy: 0.8460 - val_loss: 0.3679
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8060 - loss: 0.4066 - val_accuracy: 0.8500 - val_loss: 0.3628
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7860 - loss: 0.4443 - val_accuracy: 0.8180 - val_loss: 0.3764
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4413 - val_accuracy: 0.8360 - val_loss: 0.3751
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8040 - loss: 0.4110 - val_accuracy: 0.8280 - val_loss: 0.3847
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8020 - loss: 0.4576 - val_accuracy: 0.8560 - val_loss: 0.3635
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8020 - loss: 0.4260 - val_accuracy: 0.8500 - val_loss: 0.3581
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4239 - val_accuracy: 0.8480 - val_loss: 0.3625
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8160 - loss: 0.4045 - val_accuracy: 0.8560 - val_loss: 0.3607
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8240 - loss: 0.4140 - val_accuracy: 0.8380 - val_loss: 0.3714
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8120 - loss: 0.4121 - val_accuracy: 0.8320 - val_loss: 0.3744
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8140 - loss: 0.4130 - val_accuracy: 0.8520 - val_loss: 0.3630
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8060 - loss: 0.4318 - val_accuracy: 0.8440 - val_loss: 0.3710
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8080 - loss: 0.4265 - val_accuracy: 0.8540 - val_loss: 0.3604
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8380 - loss: 0.3968 - val_accuracy: 0.8560 - val_loss: 0.3599
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7860 - loss: 0.4390 - val_accuracy: 0.8460 - val_loss: 0.3644
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8100 - loss: 0.4289 - val_accuracy: 0.8400 - val_loss: 0.3677
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7940 - loss: 0.4493 - val_accuracy: 0.8600 - val_loss: 0.3671
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7920 - loss: 0.4320 - val_accuracy: 0.8480 - val_loss: 0.3630
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7980 - loss: 0.4398 - val_accuracy: 0.8540 - val_loss: 0.3641
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7880 - loss: 0.4390 - val_accuracy: 0.8460 - val_loss: 0.3667
# Train: 0.838, Test: 0.846

# %% [markdown]
# Visualize output

# %%
plot_decision_boundary(X, y, model, cmap='RdBu')
# Out:
# 5000/5000 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# (<Figure size 1000x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# Vary Loss function

# %%
# MSE loss --------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='MSE', optimizer=opt, metrics=['accuracy'])

# fit model
history_mse = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('MSE Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# cross-entropy loss ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_ce = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('CE Train: %.3f, Test: %.3f' % (train_acc, test_acc))


# plot training history
pyplot.figure(figsize=(10,10))
pyplot.plot(history_mse.history['accuracy'], label='MSE train', )
pyplot.plot(history_ce.history['accuracy'], label='Cross-entropy train')
pyplot.legend()
pyplot.show()
# Out:
# MSE Train: 0.844, Test: 0.852
# CE Train: 0.828, Test: 0.854

# %% [markdown]
# Vary learning rate

# %%
# LR = 0.01 --------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_001 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('learning_rate = 0.01: %.3f, Test: %.3f' % (train_acc, test_acc))


# LR = 0.5 ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.5, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_050 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('learning_rate = 0.5: %.3f, Test: %.3f' % (train_acc, test_acc))


# LR = 1 ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 1.0, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_100 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('learning_rate = 1.0: %.3f, Test: %.3f' % (train_acc, test_acc))




# plot training history
pyplot.figure(figsize=(10,10))
pyplot.plot(history_001.history['accuracy'], label='learning_rate = 0.01', )
pyplot.plot(history_050.history['accuracy'], label='learning_rate = 0.5')
pyplot.plot(history_100.history['accuracy'], label='learning_rate = 1.0')

pyplot.legend()
pyplot.show()
# Out:
# learning_rate = 0.01: 0.838, Test: 0.844
# learning_rate = 0.5: 0.826, Test: 0.832
# learning_rate = 1.0: 0.504, Test: 0.496

# %% [markdown]
# Vary momentum

# %%
# M = 0 --------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.0)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_000 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('M=0: %.3f, Test: %.3f' % (train_acc, test_acc))


# M = 0.5 ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_050 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('M=0.5: %.3f, Test: %.3f' % (train_acc, test_acc))


# M = 1 ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=1.0)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_100 = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('M=1.0: %.3f, Test: %.3f' % (train_acc, test_acc))




# plot training history
pyplot.figure(figsize=(10,10))
pyplot.plot(history_000.history['accuracy'], label='M=0', )
pyplot.plot(history_050.history['accuracy'], label='M=0.5')
pyplot.plot(history_100.history['accuracy'], label='M=1.0')

pyplot.legend()
pyplot.show()
# Out:
# M=0: 0.682, Test: 0.630
# M=0.5: 0.748, Test: 0.762
# M=1.0: 0.758, Test: 0.738

# %% [markdown]
# Vary Optimizer algorithm

# %%
# SGD loss --------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# fit model
history_SGD = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('MSE Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# Adam loss ---------------
model = Sequential()
model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))  # this includes weight initialization
model.add(Dense(1, activation='sigmoid'))
# opt = SGD(learning_rate = 0.01, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit model
history_Adam = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=100, verbose=0)

# evaluate the model
_, train_acc = model.evaluate(trainX, trainy, verbose=0)
_, test_acc = model.evaluate(testX, testy, verbose=0)
print('CE Train: %.3f, Test: %.3f' % (train_acc, test_acc))


# plot training history
pyplot.figure(figsize=(10,10))
pyplot.plot(history_SGD.history['accuracy'], label='SGD train', )
pyplot.plot(history_Adam.history['accuracy'], label='Adam train')
pyplot.legend()
pyplot.show()
# Out:
# MSE Train: 0.832, Test: 0.846
# CE Train: 0.822, Test: 0.828

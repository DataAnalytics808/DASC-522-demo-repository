# %% [markdown]
# Click "Copy to Drive" above to copy this file to your Colab account.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Bonus - Raindrop plot demo - removed due to seaborn ptitprince conflict

# %% [markdown]
# ###Preamble

# %%
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# !pip install seaborn==0.11.0
# import seaborn as sns


# !pip install ptitprince
# import ptitprince as pt
# import matplotlib.pyplot as plt
# import matplotlib.collections as clt

# %% [markdown]
# ### Load dataset, DP

# %%
# df = pd.read_excel("https://raw.githubusercontent.com/DataAnalytics808/DASC-522-demo-repository/main/data/drug_consumption.xlsx",sheet_name='drug_consumption')
# df = df.set_index('ID')

# df2 = df[['THC', 'Age', 'Gender','Education', 'Country','Ethnicity','Nscore', 'Escore', 'Oscore', 'Ascore',\
#           'Cscore', 'Impulsive', 'SS']]

# df2.info()
# df2.describe()
# df2.head()

# %% [markdown]
# Raindrop plot

# %%
# sns.set(style="whitegrid",font_scale=1.25)
# f, ax = plt.subplots(figsize=(8,16))
# sigma = .25
# ax=pt.RainCloud(data = df2, palette = 'viridis',scale = "count",
#       bw = sigma,width_viol = 0.6, orient = "h", move=0.2)
# plt.show()
